# %% [markdown]
# ## Stock market prediction using Deep Learning
#
# ### Sentimental analysis using Twitter for Stock Market Prediction
#
# This jupyter notebook implements extracting tweets of Apple company.

# %%
# !pip install tweepy

# %% [markdown]
# ### Import Libraries

# %%
#libraries
import numpy as np
import pandas as pd
import re
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from textblob import TextBlob
import datetime
import csv
import sys

# %% [markdown]
# ### User credentials from Twitter app
# Get your user credentials from the Twitter app

# %%
#User credentials to access Twitter API
access_token = "973597389226471424-4HI6QmITahXeyfg2U9cos1wJhtwUZdb"
access_token_secret = "YjtNFgmWcF5mUghtMCrwQADk6c2wToT84gSl1MGqh3Pvz"
consumer_key = "buD36prPWXKOHJhtsq1yhj4d5"
consumer_secret = "LsjuTUH1mchDCfxLHcZkUzPWFvikZLAAj5uaLuxZZ0lTtPMTrV"

# %% [markdown]
# ### User Authentication:

# %%
try:
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
except:
    print("Authentication failed")

# %% [markdown]
# ### Extract tweets using Tweepy Cursor

# %%
import csv
csvFile = open('tweets.csv', 'w')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search,q=["Apple","AAPL"],count=1000,lang="en",since_id=2018-2-1).items():
    print(tweet.created_at, tweet.text)
with open('tweets.csv',newline='') as csvFile:
    r = csv.reader(csvFile)
    data = [line for line in r]
with open('tweets.csv','w',newline='') as csvFile:
    w = csv.writer(csvFile)
    w.writerow(['Date','Text'])
    w.writerows(data)
# Out:
# 2018-04-24 02:43:02 $AAPL: After 3 waves bounce to correct decline from $178.94, #Apple can see further downside in 5 waves #elliottwave
# 2018-04-24 02:42:18 $AAPL 15 April: #Apple ended wave ((X)) rally at $178.94 in blue box and turned lower impulsively #elliottwave https://t.co/VaPhdTTpE4
# 2018-04-24 02:38:33 Apple Inks Deal for Ed Sheeran 'Songwriter' Documentary https://t.co/K70Lmg4vPS #AAPL
# 2018-04-24 02:24:15 @business It would help if $aapl @Apple didnt make subpar devices at premium prices
# 2018-04-24 02:18:53 RT @stebottaioli: #apple l reiterate my bearish view on AAPL https://t.co/0wD1wOoQm8
# 2018-04-24 01:57:22 As Rafiki told a young Simba in search of his father Mufasa , "Look harder." $AAPL https://t.co/uwPrFJgIlt
# 2018-04-24 01:46:06 iPhone Manufacturers' Slowing Sales Are a Bad Omen for Apple $AAPL - https://t.co/f8tPHzckgI
# 2018-04-24 01:22:46 RT @AirdropKitty: Register Now &amp; go Long📈 or Short📉 on #Tech #Stocks!
#
# 1 - 100x Leverage ✅
#
# ...

# %% [markdown]
# #### The extracted tweets are stored in tweets.csv for further preprocessing
