# %% [markdown]
# # Calculating the polarity of tweets

# %% [markdown]
# #### Importing all the required packages

# %%
import pandas as pd
import re
import sys
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
import csv

# %% [markdown]
# #### First Function:  Tokenizing the tweets
# i.e replacing the non word characters with space i.e replacing ("$ # @ ! & %") with space
#
# #### Second Function: Calculating Polarity of the word with the reference of AFINN dictionary
#
# AFINN is a list of English words rated for valence with an integer
# between minus five (negative) and plus five (positive). The words have
# been manually labeled by Finn Årup Nielsen in 2009-2011. The file
# is tab-separated. There are two versions:
#
# AFINN-111: Newest version with 2477 words and phrases.
#
# AFINN-96: 1468 unique words and phrases on 1480 lines. Note that there
# are 1480 lines, as some words are listed twice. The word list in not
# entirely in alphabetic ordering.

# %%
def tokenize(text):
    var = re.sub('\W+', ' ', text.lower()).split()
    return var

def afinn_sentiment(terms, afinn):

    total = 0.
    for t in terms:
        if t in afinn:
            #print(t+' found in afinn so adding '+str(afinn[t]))
            total += afinn[t]
    return total

# %% [markdown]
# #### Downloading Afinn file from url mentioned below

# %%
url = urlopen('http://www2.compute.dtu.dk/~faan/data/AFINN.zip')
zipfile = ZipFile(BytesIO(url.read()))
afinn_file = zipfile.open('AFINN/AFINN-111.txt')

afinn = dict()
for line in afinn_file:
    parts = line.strip().split()
    if len(parts) == 2:
        afinn[parts[0]] = int(parts[1])
        
afinn = {key.decode('utf-8'): value for (key, value) in afinn.items()}

# %% [markdown]
# ### Sentiment Analyser:
# Calculating polarity of each word in the tweet and according categorizing if postive negative or neutral

# %%
def sentiment_analyzer(tweet_s):
    tokens = [tokenize(t) for t in tweet_s]  # Tokenize all the tweets

    afinn_total = []
    polarity = []

    for tweet in tokens:
        total = afinn_sentiment(tweet, afinn)
        afinn_total.append(total)
        if total > 0:
            polarity.append("positive")
        elif total < 0:
            polarity.append("negative")
        else:
            polarity.append("neutral")
    afinn_total = np.array(afinn_total).transpose()   
    polarity = np.array(polarity).transpose()
    return afinn_total,polarity

# %% [markdown]
# #### Adding two new columns to already created csv with tweets
# columns = polarity of tweets and Sentiments associated

# %%
df19 = pd.read_csv("Sentiment_Analysis_of_67_Tweets_About_AAPL.csv")
df19 = df19.drop("Sentiment",axis =1)

# %%
weights, sentiments = sentiment_analyzer(df19.Tweet)
df19["Senitments"] = sentiments
df19["Weights"] = weights

# %% [markdown]
# ### Converting to new csv

# %%
df19.to_csv("AppleTweets19.csv",index=False)

# %% [markdown]
# ### Loading the above created csv

# %%
df = pd.read_csv("AppleTweets19.csv")

# %%
df
# Out:
#                    Time                                              Tweet  \
# 0   2018-04-19 20:13:52  @fitbit &amp; @apple -- two horse race --  $FI...
# 1   2018-04-19 20:13:30  $AAPL falls -2.83% today on worries that #iPho...
# 2   2018-04-19 20:13:05  I'd be all over buying $AAPL right here at $17...
# 3   2018-04-19 20:12:40  Check out r/tradingsystems on Reddit for info ...
# 4   2018-04-19 20:12:22  Join @RobinhoodApp and we'll both get a stock ...
# 43  2018-04-19 19:34:05  Join @RobinhoodApp and we'll both get a stock ...
# 44  2018-04-19 19:32:03  @UHDTrader @nFuszInc @otc_watch @OTCReporter @...
# 45  2018-04-19 19:30:15  ACTIVE TRADERS Try one of these FREE trading g...
# 46  2018-04-19 19:29:01  Tim Cook Doesn't Believe Users Want Apple to M...
# 47  2018-04-19 19:28:13  @CNBC Why $WMT Walmart should buy a 10% stake ...
# 48  2018-04-19 19:27:37  #US Afternoon: WallSt gave up early fight, tru...
# 49  2018-04-19 19:23:48  CHESLOCK on:\r\nTECHNICALS: $SPX looking to br...
# 50  2018-04-19 19:21:55  Notable $TWTR recovery underway after machines...
# 51  2018-04-19 19:21:13          Avoid $FB and $AAPL. Super bullish $GOOGL
# 52  2018-04-19 19:15:59  Join @RobinhoodApp and we'll both get a stock ...
# 53  2018-04-19 19:15:42  Research Analysts Weekly Ratings Updates for A...
# 54  2018-04-19 19:14:59  Research Analysts Weekly Ratings Updates for A...
# 55  2018-04-19 19:14:48  I love $aapl, but I am running out of reasons ...
# 56  2018-04-19 19:14:23  Research Analysts Weekly Ratings Updates for A...
# 57  2018-04-19 19:13:00  Research Analysts Weekly Ratings Updates for A...
# 58  2018-04-19 19:12:20  so it's a SCARY day and yet $VX_F which are $V...
# 59  2018-04-19 19:12:02  Apple's CEO Brushes Off the Notion of Platform...
# 60  2018-04-19 19:09:18  @njspeculator @JasonAgain $ATOM\r\n Wonder if ...
#
#    Senitments  Weights
# 0    positive      1.0
# 1    negative     -3.0
# 2    positive      2.0
# 3     neutral      0.0
# 4    positive      4.0
# 5    positive      4.0
# 6     neutral      0.0
# 7     neutral      0.0
# 8     neutral      0.0
# 9    negative     -1.0
# 10    neutral      0.0
# 11    neutral      0.0
# 12   positive      1.0
# 13   negative     -3.0
# 14    neutral      0.0
# 15    neutral      0.0
# 16    neutral      0.0
# 17   positive      1.0
# 18   positive      1.0
# 19   negative     -4.0
# 20    neutral      0.0
# 21    neutral      0.0
# 22   positive      2.0
# 23   positive      4.0
# 24   negative     -2.0
# 25    neutral      0.0
# 26   positive      4.0
# 27   positive      1.0
# 28   positive      4.0
# 29   negative     -2.0
# ..        ...      ...
# 31   negative     -1.0
# 32    neutral      0.0
# 33    neutral      0.0
# 34    neutral      0.0
# 35    neutral      0.0
# 36    neutral      0.0
# 37    neutral      0.0
# 38    neutral      0.0
# 39   positive      2.0
# 40   negative     -3.0
# 41    neutral      0.0
# 42    neutral      0.0
# 43   positive      4.0
# 44    neutral      0.0
# 45   positive      2.0
# 46   positive      1.0
# 47    neutral      0.0
# 48    neutral      0.0
# 49   positive      2.0
# 50   positive      2.0
# 51   positive      2.0
# 52   positive      4.0
# 53    neutral      0.0
# 54    neutral      0.0
# 55   positive      2.0
# 56    neutral      0.0
# 57    neutral      0.0
# 58   negative     -3.0
# 59    neutral      0.0
# 60   positive      2.0
#
# [61 rows x 4 columns]
